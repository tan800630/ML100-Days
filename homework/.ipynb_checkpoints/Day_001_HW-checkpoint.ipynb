# %% [markdown]
# # 作業1
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
#
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估

# %% [markdown]
# ### 作業1-答案
#
# #### [Humpback Whale Identification](https://www.kaggle.com/c/humpback-whale-identification)
#
# 1. 在野生動物的保育上，由於人為介入會影響到原本族群的生活模式，大多時候動物保育者們都只能以遠距觀察的方式進行記錄群體的各種行為。另外針對數量稀少的保育類動物，比起以整體族群為單位的資訊紀錄，每一個個體的成長/生活狀況更加珍貴，因此正確地從取得的照片/影片判斷是哪一個個體極為重要。
# 2. 這個比賽亦建立在動物保育的基礎上，希望能找到最佳的演算法協助辨認座頭鯨的個體編號。資料來源為[HappyWhale.com](https://happywhale.com/home)網站所提供，此網站提供了一個平台讓民眾可以上傳他們拍攝到的鯨魚照片，並且有自己的演算法和團隊辨別照片中的鯨魚是否是已知編號的鯨魚，藉此集合群眾的力量達到保育的目的。
# 3. 在此比賽中，我們手上的資料為超過2萬5千張的座頭鯨照片(為了簡化問題，照片內容應為尾段的部分，猜測可能是與他們怎麼判斷每一個體有關)，並且有超過3000個鯨魚個體的ID，參賽者們需要建立自己的演算法，並標記未看過照片中的座頭鯨可能的ID為何。
# 4. 這個競賽的任務是一個分類作業(標記ID)，其使用的判斷依據是MAP@5。

# %% [markdown]
# # 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ### 作業2-答案
#
# 1. 將業績定義在每月的收入(扣除支出成本)，另外初步先探討載客地區與時段對於每月收入(與相關變項)的影響，假設載客地區與時段會造成客源數量、單趟收入、待命時間有所不同，因而影響到業績
# 2. 大部分的變項仍然須從車隊的載客紀錄而來(如：所在區域、載客時間、單趟收入)，需要考慮的是由於目前營運上已經有一定程度的固定性(ex. 車隊習慣在那些位置待命或司機個人偏好不同)，因此也許也要考慮有沒有可能採用隨機分派的方式做資料收集。額外可能也會想取得此地區其他載客車隊的數量區間以及區域特性如住家、商業區、平均交通流量等，以便後續類推至新的地區，這些資料可能須從googlemap API上擷取。
# 3. 資料型態為連續型與類別型資料(未使用到影片、照片、音訊、文字檔案，因此大部分為結構化資料)，在前處理部分需要以時間、地區作為串接googlemap API 和車隊載客紀錄的主鍵
# 4. 上述的問題定義較簡單，針對單位時間客源數量、單趟收入、單位時間待命比例做模型建構(皆為回歸問題)，建立模型後可判斷誤差(ex. RMSE)是否符合要求，以及各項特徵的重要性與方向為何。

# %% [markdown]
# # 作業3

# %% [markdown]
# ### 作業3-答案

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    return np.mean((y-y_hat)**2)

# %%
def mean_absolute_error(y, yp):
    return np.mean(abs(y - yp))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 263.278
# The Mean absolute error is 12.322
